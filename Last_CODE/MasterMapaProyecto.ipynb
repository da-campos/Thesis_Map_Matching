# %%
import ctypes
print (ctypes.sizeof(ctypes.c_voidp))
# Out:
# 8

# %%
import psycopg2
connection = psycopg2.connect(user = "postgres",
                              password = "Sagitario137",
                              port = "5432",
                              database = "postgres")

db_cursor = connection.cursor()
# Print PostgreSQL Connection properties

db_cursor.execute("""CREATE TABLE osm_copy_way AS (SELECT * FROM planet_osm_ways);""")

db_cursor.execute("""SELECT table_name FROM information_schema.tables
   WHERE table_schema = 'public'""")

for table in db_cursor.fetchall():
    print(table)
# Out:
# ('geography_columns',)
# ('geometry_columns',)
# ('spatial_ref_sys',)
# ('planet_osm_point',)
# ('osm_copy_way',)
# ('planet_osm_polygon',)
# ('planet_osm_ways',)
# ('planet_osm_rels',)
# ('planet_osm_roads',)
# ('planet_osm_nodes',)

# %%
db_cursor.execute("""SELECT id, nodes, tags FROM osm_copy_way ORDER BY id FETCH FIRST 1000 ROW ONLY;""")
print("Selecting rows from ways table using cursor.fetchall")
way_records = db_cursor.fetchall() 
    
print("Print each row and it's columns values")
for row in way_records:
   print("Id = ", row[0], )
   print("Nodes = ", row[1])
   print("Tags  = ", row[2], "\n")
# Out:
# Selecting rows from ways table using cursor.fetchall
# Print each row and it's columns values
# Id =  2080
# Nodes =  [571329, 571328, 571327, 545676]
# Tags  =  ['name', 'Møllehusene', 'highway', 'unclassified']
#
# Id =  2081
# Nodes =  [546419, 3763710931, 3763710939, 3763710938, 3763710943, 3763710945, 3763710947, 1015329269, 4038756297, 574928, 331345585, 570284, 6356842769, 6356842768, 6356842770, 6356842776, 765091656, 3439361903, 570283, 2122682936, 1755113164, 1296754626, 570288, 4038756308, 2619629970, 482455446, 7155740565, 3317651087, 570289]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'maxspeed', '50', 'name', 'Møllehusvej', 'source', 'Local knowledge', 'surface', 'asphalt']
#
# Id =  2082
# Nodes =  [570226, 3253490576, 26372628, 1964063432, 331345959, 570224, 570222, 570221, 2257598730]
# Tags  =  ['cycleway', 'track', 'highway', 'secondary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Byvolden', 'ref', 'O1', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  2124
# Nodes =  [545667, 5483630462, 7155740567, 3872585800, 545668]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '30', 'name', 'Støden', 'sidewalk', 'both', 'source:maxspeed', 'sign', 'surface', 'asphalt']
#
# Id =  2161
# Nodes =  [545670, 5483645969, 5483645960]
# Tags  =  ['cycleway:right', 'track', 'highway', 'secondary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Borgediget', 'oneway', 'yes', 'ref', 'O1', 'sidewalk', 'right', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  2796
# Nodes =  [25981317, 422248375, 1356013905, 4677457060, 1356013901, 687890]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Fruebjergvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  2861
# Nodes =  [125448, 299587330, 4519617435, 7130882727, 279329813, 2583448446, 4519617441, 692712, 8078521, 4519617443]
# Tags  =  ['cycleway:right', 'track', 'highway', 'primary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Tomsgårdsvej', 'oneway', 'yes', 'ref', 'O2', 'sidewalk', 'right', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  2862
# Nodes =  [125429, 716767714]
# Tags  =  ['cycleway:right', 'none', 'highway', 'tertiary', 'lanes', '2', 'maxspeed', '50', 'oneway', 'yes', 'placement', 'middle_of:2', 'sidewalk', 'separate', 'surface', 'asphalt', 'turn:lanes', 'left|']
#
# Id =  3735
# Nodes =  [705268, 1638786020, 1638785886, 1638785888, 413321212]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Norsvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  21457
# Nodes =  [777863, 4892498959, 777870, 4948246920, 777885, 777887, 777889, 777893, 777901, 5037197299, 777910, 4948246919, 777912, 4948246918, 777917, 777921, 4948247021, 777944]
# Tags  =  ['access', 'destination', 'highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Blidahpark', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  21569
# Nodes =  [779036, 779042, 4132331864, 4948247035, 779044, 4132331863, 779048]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Stigaardsvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  22070
# Nodes =  [781050, 312410313]
# Tags  =  ['bicycle', 'yes', 'highway', 'footway', 'created_by', 'osm2go v0.6-2']
#
# Id =  24024
# Nodes =  [791958, 791959, 1634935462, 791961, 1634175804, 791962]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Kastanievej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  24026
# Nodes =  [791964, 1634925851, 1634925835]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Uraniavej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'paved']
#
# Id =  24028
# Nodes =  [725128, 4358126082, 4536131552, 8136360]
# Tags  =  ['bicycle', 'yes', 'cycleway:right', 'shared_lane', 'foot', 'yes', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Kingosgade', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'wikidata', 'Q12321884', 'wikipedia', 'da:Kingosgade']
#
# Id =  24029
# Nodes =  [792018, 2721556261, 2721556263, 4358126077, 25256979]
# Tags  =  ['cycleway', 'no', 'highway', 'tertiary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Alhambravej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  24030
# Nodes =  [833442027, 2317412719, 1626972710, 1626972741, 1626972717, 1626972731, 1626972734, 1626972739, 2999926387, 1626972725, 799180818, 799180844, 1626972722, 1626972729, 25256989, 3244018264, 791971]
# Tags  =  ['cycleway', 'track', 'highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Madvigs Alle', 'oneway', 'no', 'sidewalk', 'both', 'surface', 'paved']
#
# Id =  24033
# Nodes =  [3353617264, 4450175925, 791972, 3714216404, 791974, 1531572407]
# Tags  =  ['lit', 'yes', 'name', 'Vesterfælledvej', 'lanes', '2', 'highway', 'tertiary', 'surface', 'asphalt', 'cycleway', 'no', 'maxspeed', '50', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban']
#
# Id =  24034
# Nodes =  [792009, 4510392584, 2317403760, 4427861608, 2317398556, 2317398553, 312322529, 2317398559, 791978, 2317404869, 2317396807, 791975]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '40', 'name', 'Lyrskovgade', 'oneway', 'no', 'sidewalk', 'both', 'source:maxspeed', 'sign', 'surface', 'asphalt', 'vehicle', 'yes', 'wikidata', 'Q29034342', 'wikipedia', 'da:Lyrskovgade']
#
# Id =  24035
# Nodes =  [791980, 1059591369, 1059565486, 791978]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Ejderstedgade', 'oneway', 'yes', 'oneway:bicycle', 'no', 'surface', 'asphalt']
#
# Id =  24036
# Nodes =  [781055, 792028]
# Tags  =  ['highway', 'living_street', 'lit', 'yes', 'name', 'Helenevej', 'surface', 'paving_stones']
#
# Id =  24208
# Nodes =  [3605573591, 5308847830, 5308847831, 1575415382, 7125997132, 1629465100, 1629465139, 1629433709, 1640375051]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Pile Alle', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  24211
# Nodes =  [725128, 4876445704]
# Tags  =  ['bicycle', 'yes', 'cycleway', 'track', 'cycleway:left', 'lane', 'foot', 'yes', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Enghavevej', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  24213
# Nodes =  [8136339, 2405293257, 8122216, 298795972]
# Tags  =  ['cycleway', 'no', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Frederiksberg Alle', 'oneway', 'yes', 'sidewalk', 'right', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29639
# Nodes =  [705281, 1638030963, 1638030978, 1638030829, 1638392942, 1640196404, 6463347764, 814200, 6463347763, 6988660571, 6988660572, 814201, 6988660573, 1639641048, 814202, 6988660570, 814203, 1640310445, 814223, 1638778263, 705272]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Niels Ebbesens Vej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29640
# Nodes =  [1621332206, 288264783, 1433810212, 5745826573]
# Tags  =  ['cycleway', 'lane', 'highway', 'tertiary', 'lit', 'yes', 'maxspeed', '40', 'name', 'Thorvaldsensvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  29642
# Nodes =  [814189, 1638785866, 1638794524, 814229, 413321214]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'motorcar', 'private', 'name', 'Sveasvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  29647
# Nodes =  [814159, 1639673641, 1639749703, 1331462677, 1640315843, 1331462673, 4907815958, 1639749702, 814221]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Svanholmsvej', 'oneway', 'yes', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29649
# Nodes =  [7489412554, 814163, 1639760235, 833401328]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Schønbergsgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29650
# Nodes =  [814184, 2955578332, 4794005468, 7319698783]
# Tags  =  ['highway', 'residential', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Julius Thomsens Plads', 'oneway', 'yes', 'sidewalk', 'right', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29651
# Nodes =  [814180, 1637652698, 1637820553, 1637820555, 1637820548, 1637652609, 814208]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Forchhammersvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29654
# Nodes =  [814204, 1637832272, 814186, 1637448565, 1637448470, 814187]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Sankt Markus Alle', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29655
# Nodes =  [814181, 1637832311, 1637781889, 781567]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Johnstrups Alle', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29657
# Nodes =  [7319698782, 1637448387, 1637448527, 1637811027, 1637811039, 412352945, 1637448526, 1190852525, 6900335992, 1637804866, 814188, 1637804853, 412352937, 5253847764, 814210, 421433799, 814211]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '40', 'maxweight', '16', 'name', 'Vodroffsvej', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  29660
# Nodes =  [814187, 7319769186, 1637448524, 1637448534, 1637448400, 7319769185, 4794005467, 814308]
# Tags  =  ['highway', 'residential', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Julius Thomsens Plads', 'oneway', 'yes', 'sidewalk', 'right', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29661
# Nodes =  [814200, 1640196405, 1638392872, 1638392897, 1639068622, 1640198159, 1639068836, 1640198173, 1638387570, 1638383971, 1638383972, 1639081699, 1638377391, 1640290673, 1640199214, 1639081629, 1640199219, 1640290685, 814162]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Lykkesholms Alle', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'wikidata', 'Q62851604']
#
# Id =  29662
# Nodes =  [814156, 1638732728, 1638732744, 1638732747, 1638732741, 814201]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Sankt Knuds Vej', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29663
# Nodes =  [6988660569, 1640310458, 1639641301, 1638841040, 1639641045, 814219, 1640310451, 1639641033, 7320544784, 814193]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Forhåbningsholms Alle', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29665
# Nodes =  [814203, 1923889069, 3468204143, 814222, 814226, 814158]
# Tags  =  ['cycleway', 'opposite_lane', 'highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Carl Plougs Vej', 'oneway', 'yes', 'oneway:bicycle', 'no', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29666
# Nodes =  [814227, 1062975290, 814320, 1062975409, 1292883135, 1292883266, 1062975368, 814319, 1062975101, 1062975398]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'mapillary', 'EMF0hygoGCxJYKUKtac8oE', 'maxspeed', '50', 'name', 'Danas Plads', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  29667
# Nodes =  [814175, 814214, 814215, 814216, 7056567225, 7056567224, 814217]
# Tags  =  ['bicycle', 'yes', 'highway', 'footway', 'incline', 'yes', 'surface', 'ground']
#
# Id =  29670
# Nodes =  [7319769201, 1634175784, 791965]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Lindevej', 'oneway', 'no', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  37391
# Nodes =  [843601, 1331462685, 1281444687, 1331462667, 706670445, 843602, 1281444676, 1281444691, 843604, 1624383996, 1281444672, 706670395, 1281444667, 1331462671, 843599, 1331462676, 1281444684, 1331462681, 706670318, 1331462679, 843601]
# Tags  =  ['bicycle', 'designated', 'cycleway', 'lane', 'highway', 'residential', 'junction', 'roundabout', 'lit', 'yes', 'maxspeed', '40', 'sidewalk', 'right', 'source:maxspeed', 'sign', 'surface', 'asphalt']
#
# Id =  37392
# Nodes =  [1624939713, 843606, 4300898464, 843588, 1624424190, 7422421015, 843589, 367355930, 843590]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Sagasvej', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  37394
# Nodes =  [843586, 843594]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Ceresvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  37395
# Nodes =  [1624963037, 843577, 7489468384]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Rathsacksvej', 'oneway', 'yes', 'sidewalk', 'both', 'source:maxspeed', 'sign', 'surface', 'asphalt']
#
# Id =  37397
# Nodes =  [843582, 706670512]
# Tags  =  ['highway', 'residential', 'maxspeed', '40', 'name', 'Acaciavej', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  37434
# Nodes =  [843584, 1624239678]
# Tags  =  ['highway', 'residential', 'maxspeed', '40', 'name', 'Grundtvigs Sidevej', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  37435
# Nodes =  [1625123046, 4184934477, 1624987832, 5257844079, 843579]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Henrik Steffens Vej', 'sidewalk', 'both', 'source:maxspeed', 'sign', 'surface', 'asphalt']
#
# Id =  37450
# Nodes =  [781059, 1635055398, 1634953711, 781058]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Bomhoffs Have', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  53790
# Nodes =  [4336090, 3710410305, 1913278320, 904202]
# Tags  =  ['highway', 'tertiary', 'lanes', '3', 'lanes:backward', '1', 'lanes:forward', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Strandbygade', 'surface', 'asphalt', 'turn:lanes:forward', 'left|none']
#
# Id =  53800
# Nodes =  [904202, 5240299239, 5240299235, 1913278317, 1061191]
# Tags  =  ['cycleway', 'none', 'highway', 'tertiary', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Skolegade', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  53807
# Nodes =  [1876978, 14962539, 31004226, 14962536, 7456595008, 14962535]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Stormgade', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  53813
# Nodes =  [691257175, 1203068123, 1203068276, 1203198465]
# Tags  =  ['highway', 'secondary', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Frodesgade', 'oneway', 'yes', 'ref', '447', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  59335
# Nodes =  [117973, 1204016897, 1203068120, 1204016893]
# Tags  =  ['destination', 'Blåvand;Hjerting', 'destination:ref', '447', 'highway', 'secondary', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Hjertingvej', 'oneway', 'yes', 'ref', '447', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  59887
# Nodes =  [1020791255, 929287]
# Tags  =  ['highway', 'secondary', 'lanes', '4', 'lit', 'yes', 'maxspeed', '50', 'name', 'Jernbanegade', 'oneway', 'yes', 'ref', '447', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  86403
# Nodes =  [1060535, 1021783399, 344669039, 5077689, 4333442, 4897956525]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Torvegade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  86419
# Nodes =  [2591620, 2289552960, 4928988327, 1568098887, 1568098900, 11676849, 11676846, 5511960689, 1203216175, 1059944]
# Tags  =  ['cycleway', 'none', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Nørregade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  86448
# Nodes =  [13796198, 3741143900, 59710081, 117991, 1913278100, 1060910, 30465949, 1951291473, 6470198153]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'maxspeed', '50', 'name', 'Englandsgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  86467
# Nodes =  [26581859, 1568179238, 117987, 1957369626, 6299449795, 1957369582, 14807337, 1022029150, 7466483263, 1022029011, 1022028991, 1022029035, 1022029195, 1022029047, 1080048537, 1022029152, 7466483262, 6299377500]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Borgergade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  86492
# Nodes =  [117984, 5284603124, 2289552958, 1021962296, 1972460489, 1972466928, 1021962353, 5077682, 4890136394]
# Tags  =  ['cycleway', 'none', 'highway', 'tertiary', 'lanes', '2', 'maxspeed', '50', 'name', 'Havnegade', 'surface', 'asphalt']
#
# Id =  144718
# Nodes =  [4343152, 4343151, 2236847684, 4343149, 4343148, 4343146, 4343145, 4343143, 4343137, 7104048320, 4343139, 1315949, 1315947, 7104048319, 1315944, 21455756, 2236847667, 1315938, 1315864]
# Tags  =  ['highway', 'unclassified', 'lit', 'no', 'maxspeed', '80', 'name', 'Søndre Kjersingvej', 'oneway', 'no', 'source:maxspeed', 'DK:rural', 'surface', 'asphalt']
#
# Id =  144758
# Nodes =  [1315861, 6089909309, 6089909304, 38702913, 38702915, 1316045, 38702918, 38702923, 1316047, 38702926, 1316048, 38702931, 38702933, 38702937, 1315857, 38702944]
# Tags  =  ['highway', 'residential', 'name', 'Lindelunden']
#
# Id =  144766
# Nodes =  [2384943, 3961885442, 3961885439, 3961885558, 2357713915, 3961885577, 2583450, 1023153283, 2583448, 4158308535, 4158308541, 2583446, 4486199689, 2384933, 1554465759, 4158308731, 4158308842, 4158308896, 2384932, 2384931, 1877062]
# Tags  =  ['name', 'Degnevej', 'oneway', 'no', 'source', 'https://www.ucsyd.dk/uddannelser/paedagog/artikel/studerende-faar-hastigheden-sat-ned/', 'highway', 'tertiary', 'cycleway', 'lane', 'maxspeed', '50']
#
# Id =  144826
# Nodes =  [1877002, 1877001, 1877000, 4158309379, 6300302505, 1876999, 6300302504, 1876998, 6300302511, 4908705288, 1017313020, 1876997, 6302075861, 6300302519, 6300302513, 1876996, 3001993059, 6300302536, 1876995, 6300302529, 1876994, 6302075852, 3001993060, 1876993, 7235732456, 2384895]
# Tags  =  ['highway', 'tertiary', 'lit', 'yes', 'maxspeed', '60', 'name', 'Falkevej', 'surface', 'asphalt']
#
# Id =  179761
# Nodes =  [662892, 336470055, 336470060, 654740]
# Tags  =  ['lit', 'yes', 'name', 'Byhøjen', 'highway', 'residential', 'sidewalk', 'both']
#
# Id =  225644
# Nodes =  [1696144144, 5550933780, 1036140928, 1036140936, 654730, 4868154909, 1142637930, 1036141004, 654732, 1696144157, 654733, 278504064, 1036140819, 654734, 1036140921, 1036140971, 4513737638]
# Tags  =  ['cycleway:right', 'track', 'highway', 'tertiary', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Peter Bangs Vej', 'oneway', 'yes', 'sidewalk', 'right', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  259069
# Nodes =  [1062327, 26200185]
# Tags  =  ['highway', 'unclassified', 'name', 'Remisevej', 'surface', 'asphalt']
#
# Id =  259071
# Nodes =  [1876493, 1876494, 1142119902, 6629168139, 1876495, 6629168140, 1876496, 5508357687, 931730]
# Tags  =  ['highway', 'tertiary', 'lanes', '3', 'lanes:backward', '1', 'lanes:forward', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Nørrebrogade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'turn:lanes:forward', 'left|right']
#
# Id =  259081
# Nodes =  [935408, 4353564954, 4158227652, 1876498, 2574657, 1876511, 1876510]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Søndergårds Alle', 'surface', 'asphalt']
#
# Id =  259084
# Nodes =  [21414864, 1877077]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Baggesens Alle', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  259087
# Nodes =  [1876509, 5080397, 1876502, 10466967, 10466964, 1876511, 4098979367, 10304318, 4343125, 10465030]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Carit Etlars Alle', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  259088
# Nodes =  [30751219, 1203274546, 7152717435, 7152717429, 7152717444, 1062376]
# Tags  =  ['highway', 'tertiary', 'lanes', '3', 'lanes:backward', '2', 'lanes:forward', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Jagtvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'turn:lanes:backward', 'left|right']
#
# Id =  259090
# Nodes =  [1877017, 5243205078, 6147029, 203680203, 21421860, 1876654, 2385024]
# Tags  =  ['hgv', 'destination', 'highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Enebærvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  259093
# Nodes =  [1876978, 1203209047, 1876977, 4466641188, 5048141]
# Tags  =  ['cycleway', 'lane', 'highway', 'tertiary', 'lanes', '4', 'lanes:backward', '3', 'lanes:forward', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Strandby Kirkevej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'turn:lanes:backward', 'left|through|right']
#
# Id =  259094
# Nodes =  [1877031, 1023047046]
# Tags  =  ['highway', 'tertiary', 'maxspeed', '50', 'name', 'Sportsvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  259096
# Nodes =  [13886038, 12982347, 12982346, 1023047060, 4450712831]
# Tags  =  ['highway', 'secondary', 'maxspeed', '60', 'name', 'Storegade', 'ref', '191', 'source:maxspeed', 'sign', 'surface', 'asphalt']
#
# Id =  259099
# Nodes =  [117941, 4824552384, 203680040]
# Tags  =  ['cycleway', 'lane', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Gammel Vardevej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  259100
# Nodes =  [1059876, 1402385914, 1059871]
# Tags  =  ['highway', 'residential', 'name', 'Bjarkesgade', 'surface', 'asphalt']
#
# Id =  259101
# Nodes =  [1062351, 6450125834, 8078141, 5258329951, 8078140, 25643604, 1062382, 1062383, 1425526162, 6325332048, 1062385, 3626507408, 3626507405, 1876590]
# Tags  =  ['highway', 'residential', 'name', 'Langelandsvej']
#
# Id =  259106
# Nodes =  [118006, 2501560302, 1422128101, 4900095256, 1102161855, 929925]
# Tags  =  ['bicycle', 'no', 'highway', 'secondary', 'lanes', '2', 'maxspeed', '60', 'name', 'Jernevej', 'oneway', 'yes', 'ref', '191', 'surface', 'asphalt']
#
# Id =  259107
# Nodes =  [931852, 1023047043]
# Tags  =  ['cycleway:right', 'track', 'highway', 'secondary', 'lanes', '1', 'maxspeed', '60', 'name', 'Jernevej', 'oneway', 'yes', 'ref', '191', 'surface', 'asphalt']
#
# Id =  259108
# Nodes =  [1020492125, 1121765962, 1121765976, 1121765876, 1020492163, 1121765971, 1121765938, 1121766065, 1121765837, 1020492171, 1121765907, 1121766063, 1121765880, 1121765934, 1020492075, 1121766068, 1121766067, 1121765932, 1020492125]
# Tags  =  ['highway', 'unclassified', 'junction', 'roundabout']
#
# Id =  259109
# Nodes =  [20697183, 1020492247, 20697182, 20697181, 5878225842, 1142005632, 20697178, 1142005598, 1877088, 5360009003, 1142005514, 5360008991, 5360008994, 1649521992, 17903017, 1649521993, 1142005594, 1649521994, 1877090]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '80', 'name', 'Måde Industrivej', 'source:maxspeed', 'DK:rural', 'surface', 'asphalt']
#
# Id =  259110
# Nodes =  [1876730, 6450125813, 1877013, 7476319535, 1942492700, 1877012, 2237049473, 13197554, 7483170, 1877010, 1877009, 2384881, 2384882, 2384883, 27433266, 27433265, 2384885, 2384886]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Kvaglundvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  259111
# Nodes =  [1876988, 1554711587, 4158309314, 1877003, 4158309201, 4158309060, 4158308993, 1877004, 10470152, 1877005, 4158308889, 1877006, 1877007, 4158308798, 1877008, 14808516, 1877009]
# Tags  =  ['name', 'Vibevej', 'highway', 'residential']
#
# Id =  314371
# Nodes =  [2589211, 4900308661]
# Tags  =  ['bicycle', 'no', 'highway', 'tertiary', 'lanes', '2', 'maxspeed', '60', 'name', 'Gjesing Ringvej', 'surface', 'asphalt']
#
# Id =  314372
# Nodes =  [1062391, 6325332054, 6325332050, 5258329952, 1062356]
# Tags  =  ['highway', 'residential', 'name', 'Godthåbs Alle']
#
# Id =  328208
# Nodes =  [545679, 26372627]
# Tags  =  ['name', 'Blågårdsstræde', 'highway', 'unclassified']
#
# Id =  328209
# Nodes =  [545679, 636170, 8083370, 3303915116, 545680, 3763705239, 6063304611, 545678]
# Tags  =  ['cycleway:left', 'opposite_lane', 'highway', 'residential', 'lit', 'yes', 'name', 'Blågårdsstræde', 'oneway', 'yes', 'oneway:bicycle', 'no', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  328210
# Nodes =  [545650, 3253355067, 1015608260]
# Tags  =  ['highway', 'unclassified', 'lit', 'yes', 'maxspeed', '50', 'name', 'Provstestræde', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  328211
# Nodes =  [545652, 545653, 545662, 545661, 545660, 545654, 545655]
# Tags  =  ['name', 'Provstevænget', 'highway', 'unclassified']
#
# Id =  328394
# Nodes =  [574922, 1755120271, 5262328961, 5262328952, 5262328955, 331345150, 5262328958, 5262328949, 574923, 1755120277, 5518086263, 5518086249, 3872585647, 5323510890, 546421]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'name', 'Fælledvej', 'surface', 'asphalt']
#
# Id =  328395
# Nodes =  [546344, 546357, 546358, 546359, 1486452470, 546360, 546361, 546363, 5473078565, 5473078566, 546371, 546348]
# Tags  =  ['highway', 'residential', 'name', 'Henrik Nielsens Vej']
#
# Id =  328396
# Nodes =  [546345, 546369, 2257598601, 546368, 546367, 546366, 546365, 546364, 2257598661, 1297771726, 546347]
# Tags  =  ['name', 'I.P. Hansens Vej', 'highway', 'residential']
#
# Id =  328398
# Nodes =  [570227, 2215402, 1286235845, 3303998004, 2178599556, 679300, 563804590, 2178599815, 2208162250, 2208162249, 2208162247, 1891194497, 2187682754, 293652856, 1394270983, 4270445540, 2188699041, 2188698936, 4038805601, 2188699028, 286581951, 2188699037, 2188698992, 2188698972, 2171050323, 2188699002, 2188699034, 2188699024, 570235]
# Tags  =  ['cycleway', 'track', 'highway', 'primary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Søndre Ringvej', 'ref', 'O2', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  328504
# Nodes =  [545648, 308693407, 570266, 7124757540, 2196061212, 4962337466, 2211582650, 570268, 3878384757]
# Tags  =  ['cycleway', 'track', 'highway', 'secondary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Jernbanegade', 'ref', 'O1', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  328505
# Nodes =  [570254, 2214369002, 3901952635, 570253, 4947003179, 570252]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Hestetorvet', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  328558
# Nodes =  [546341, 546353, 1757074232, 545665, 2257598667, 546349, 546346]
# Tags  =  ['name', 'Helligkorsvej', 'highway', 'residential']
#
# Id =  328620
# Nodes =  [4038805599, 315151171, 1297733175, 4038756299, 4038756304, 3317650979, 570431, 1297657814, 570432, 3317650992, 319987783]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'maxspeed', '50', 'name', 'Låddenhøj', 'oneway', 'no', 'surface', 'asphalt']
#
# Id =  328621
# Nodes =  [546356, 1486452454, 546355, 546354, 1486452467, 546344, 546345, 4603997784, 6155724930, 2257598619, 2257598631, 546346, 546351, 2257598690, 1297771728, 5472903650, 576472, 5473078627, 3393734740, 3393734742, 286580617, 1297771731, 576469]
# Tags  =  ['highway', 'residential', 'maxspeed', '50', 'name', 'Sønderlundsvej']
#
# Id =  328622
# Nodes =  [546349, 546350]
# Tags  =  ['name', 'Rønne Alle', 'highway', 'residential', 'created_by', 'JOSM']
#
# Id =  328678
# Nodes =  [315151171, 3317650971, 286580948, 1297743089, 3317650974, 3317650975]
# Tags  =  ['foot', 'yes', 'name', 'Vestergade', 'width', '4 m', 'source', 'Local knowledge', 'highway', 'cycleway', 'surface', 'asphalt']
#
# Id =  328716
# Nodes =  [570294, 1297794897, 4675613485, 1469421474, 570293, 1469416269, 3432413897, 446990533, 446990146, 446990469, 570511]
# Tags  =  ['highway', 'unclassified', 'motor_vehicle', 'destination', 'name', 'Clermontgade']
#
# Id =  328862
# Nodes =  [545591, 2971847333, 3882239731, 545593, 545594, 545595, 545596]
# Tags  =  ['highway', 'unclassified', 'lit', 'yes', 'maxspeed', '50', 'name', 'Rådmandshaven', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  328887
# Nodes =  [570269, 1964115880, 570266]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Kornerups Vænge', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  328938
# Nodes =  [3878384757, 2400302305, 476454261, 6576671142, 570272]
# Tags  =  ['cycleway:right', 'track', 'highway', 'residential', 'maxspeed', '30', 'name', 'Allehelgensgade', 'oneway', 'yes', 'oneway:bicycle', 'no', 'oneway:bus', 'no', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  328966
# Nodes =  [545666, 570269, 570270, 4038756301, 2246691719, 3885289567, 570271, 570272]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '30', 'name', 'Bredgade', 'oneway', 'yes', 'sidewalk', 'both', 'source:maxspeed', 'sign', 'surface', 'asphalt', 'zone:maxspeed', 'DK:30']
#
# Id =  329003
# Nodes =  [570272, 4604000167, 570273, 570274, 570275, 570276, 3303915090, 26369936, 570259]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '30', 'name', 'Grønnegade', 'source:maxspeed', 'sign', 'surface', 'asphalt', 'zone:maxspeed', 'DK:30']
#
# Id =  329153
# Nodes =  [570218, 447021300, 3303915120, 570436, 570435, 3872585824, 447021450, 3872585823, 570434, 570226]
# Tags  =  ['cycleway', 'track', 'highway', 'secondary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Sankt Mortens Vej', 'ref', 'O1', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  329154
# Nodes =  [570457, 5984118284, 3382075405, 570463, 1296706564, 570462, 570461, 2619630194, 570460, 2619630186, 570459]
# Tags  =  ['cycleway', 'track', 'highway', 'secondary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Sankt Clara Vej', 'ref', 'O1', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  345265
# Nodes =  [557856, 538132, 3082176189, 247108980, 245208583, 247108975, 245208576, 557720, 256423309, 538131]
# Tags  =  ['highway', 'residential', 'lit', 'sunset-sunrise', 'maxspeed', '50', 'name', 'Skovgyden', 'surface', 'asphalt']
#
# Id =  367982
# Nodes =  [2384889, 4205139768, 1118321417, 2384891, 4205139786, 2384892, 7235732457, 7235732443, 2384895]
# Tags  =  ['highway', 'unclassified', 'name', 'Høgevej']
#
# Id =  367983
# Nodes =  [2384883, 4158308916, 14956354, 2384904, 4158308913, 4158308915, 2384910]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Gefions Alle', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  367984
# Nodes =  [2384882, 2384906, 4158308815, 4158308822, 2384907, 1876962]
# Tags  =  ['highway', 'residential', 'name', 'Mimers Alle', 'surface', 'asphalt']
#
# Id =  367985
# Nodes =  [2384881, 21063429, 2384898, 34203405, 17896295, 1876959]
# Tags  =  ['highway', 'residential', 'name', 'Hejmdals Alle', 'surface', 'asphalt']
#
# Id =  367986
# Nodes =  [1877010, 2384918, 13197559, 2384899, 2384903, 13197562, 2384917, 2384916]
# Tags  =  ['highway', 'residential', 'name', 'Fortuna Alle', 'surface', 'asphalt']
#
# Id =  367987
# Nodes =  [13197562, 2384911, 6325332591, 6325332589, 6325332593, 1876970]
# Tags  =  ['highway', 'residential', 'name', 'Vølundsvej', 'surface', 'asphalt']
#
# Id =  367988
# Nodes =  [2384915, 2384913, 2384911]
# Tags  =  ['name', 'Palnatokes Alle', 'highway', 'residential']
#
# Id =  367989
# Nodes =  [1876969, 1876970, 6325332585, 1876954, 6325332076, 1876971]
# Tags  =  ['highway', 'residential', 'name', 'Hermodsvej']
#
# Id =  367990
# Nodes =  [1877048, 5105333091, 5105333092, 5105333047, 2583454, 1877046, 6302293186, 1877045, 1877044, 2158877, 6302293177, 1024772508, 6302293173, 6302293167, 1877043, 6302293164, 6302293162, 1877042, 6302293157, 7152717498, 2583459, 1203274482, 7152717492, 1203274533, 1203274508, 1877030]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Hedelundvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  367994
# Nodes =  [2384965, 5290327144, 5511960695, 5290327132, 6299323495]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Norgesgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  367995
# Nodes =  [2384954, 1907399664, 1907399589, 2384955]
# Tags  =  ['name', 'Knudsgade', 'highway', 'residential']
#
# Id =  367996
# Nodes =  [2384952, 4098420402, 2384955, 4098420401, 1907399508]
# Tags  =  ['highway', 'residential', 'name', 'Valdemarsgade', 'surface', 'asphalt']
#
# Id =  367997
# Nodes =  [4898472155, 5511960740, 5048133, 4098980590, 31004167, 2384959]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Haraldsgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  367998
# Nodes =  [4257408135, 1022061897, 1022061787, 2384963, 25075282, 2384960, 2384959, 14956006, 6299323498]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Kirkegade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  368000
# Nodes =  [1062342, 7616814552, 2384980]
# Tags  =  ['cycleway', 'lane', 'highway', 'tertiary', 'lanes', '4', 'lanes:backward', '3', 'lanes:forward', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Spangsbjerg Kirkevej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'turn:lanes:backward', 'left||right']
#
# Id =  368001
# Nodes =  [2385009, 1334697902, 2385008, 3792135869, 2385007, 30390791, 3792156024, 2385006, 1251873536, 30390812, 5423045317, 30390819, 1251873738, 1334697918, 2385005, 1334703845, 30390808, 2385004, 1334754398, 1334721043, 4709229349, 1334721091, 4705066127, 2385003, 2385002, 1334721070, 4705066124, 2385000]
# Tags  =  ['highway', 'unclassified', 'maxspeed', '50', 'name', 'Niels Bohrs Vej']
#
# Id =  368002
# Nodes =  [1025281371, 1025281377, 25095512, 25095459, 1334623602, 3781799417, 25095460, 1025281359, 7496793618, 2502631632, 2385013]
# Tags  =  ['highway', 'residential', 'name', 'Hospitalsvej']
#
# Id =  368003
# Nodes =  [1876654, 4927521700, 1877014]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Slåenvej', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  368008
# Nodes =  [51502750, 1062371, 1942533649, 2385030, 1942552490, 21035964, 3789907062, 5943104, 2385031, 4353155, 3740996201, 1876946]
# Tags  =  ['name', 'Kirkebakken', 'highway', 'residential']
#
# Id =  420540
# Nodes =  [2563334, 5116127167, 2563332, 4108803533, 4108803531, 2563331, 4108803532, 2563330, 4108803535, 2563329, 2563327]
# Tags  =  ['destination', 'Esbjerg', 'destination:ref', 'E20', 'highway', 'motorway_link', 'oneway', 'yes', 'operator', 'Vejdirektoratet', 'operator:en', 'The Danish Road Directorate', 'operator:type', 'public', 'operator:wikidata', 'Q1630101', 'operator:wikipedia', 'da:Vejdirektoratet', 'operator:wikipedia:en', 'Vejdirektoratet', 'surface', 'asphalt']
#
# Id =  423683
# Nodes =  [1876938, 17903455, 6568220, 4157836699, 1876512, 5056441677, 1876510]
# Tags  =  ['highway', 'residential', 'name', 'Hostrups Alle']
#
# Id =  423684
# Nodes =  [2574659, 2574660]
# Tags  =  ['name', 'Munkevej', 'highway', 'residential']
#
# Id =  424411
# Nodes =  [2576952, 1020492197, 2448604792, 2576951]
# Tags  =  ['name', 'Sønderdalen', 'highway', 'residential']
#
# Id =  424412
# Nodes =  [2576953, 1116377881, 1022771030, 2576951, 2455239617, 4160693675, 4160693676, 6299227764, 6568228]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Søndervangen', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  424413
# Nodes =  [2576943, 3001992992, 4912907405, 3001992994, 4912907534, 2576947, 2576948, 3678939336, 5335589266, 2576949, 1876930]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Bøndergårdsvej', 'surface', 'asphalt']
#
# Id =  424414
# Nodes =  [2385033, 2576954]
# Tags  =  ['name', 'Sønderhaven', 'highway', 'residential']
#
# Id =  425216
# Nodes =  [2579484, 7152717477, 7152717474, 7152717459, 7152717458, 7152717473, 2579470, 2579469, 4157728612, 4157728620, 2579467, 4157728634, 2579466, 4157728640, 2579464, 1370428952, 1370429025, 1102161993, 2579460]
# Tags  =  ['highway', 'unclassified', 'lit', 'yes', 'maxspeed', '50', 'name', 'Energivej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  425217
# Nodes =  [2579456, 2579485, 4160693677, 2579486]
# Tags  =  ['name', 'Mariagervej', 'highway', 'residential']
#
# Id =  425218
# Nodes =  [2579492, 2579487, 4160693667, 2579486, 691524886]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Århusvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  425219
# Nodes =  [2579487, 4160693683, 2579489, 2579491]
# Tags  =  ['name', 'Grenåvej', 'highway', 'residential']
#
# Id =  425220
# Nodes =  [2579459, 4160693637, 4160693648, 1370370892, 1370370914, 929918]
# Tags  =  ['name', 'Skanderborgvej', 'highway', 'residential']
#
# Id =  425527
# Nodes =  [1876508, 5335589056, 2580546, 2580548, 4025835501, 5335589150, 5335589100, 5335589158, 2580549, 5335589160, 5335589103, 2580550, 2041038007, 2357713873, 5335589191, 5335589193, 3626507293, 2580552, 5335589195, 5335589211, 5335589063, 5335589062, 5335589048, 2580553, 2580554, 5335589060, 5335589059, 5335589057, 2580548]
# Tags  =  ['highway', 'residential', 'name', 'Præstebakken']
#
# Id =  425528
# Nodes =  [2580560, 3740996213, 2502570803, 2580559, 2357713882]
# Tags  =  ['name', 'Poppelvej', 'highway', 'residential']
#
# Id =  425529
# Nodes =  [2580561, 3740996215, 2502570818, 2357713899, 45436492, 2580564]
# Tags  =  ['name', 'Pilevej', 'highway', 'residential']
#
# Id =  425531
# Nodes =  [2580565, 5282444138, 2580560, 5309474, 2580561, 3740996216, 3740998427, 2580563]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Gammel Novrupvej', 'surface', 'asphalt']
#
# Id =  425532
# Nodes =  [2580557, 3740998439, 5282444010, 2580565, 935517]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Paghs Alle', 'surface', 'asphalt']
#
# Id =  425533
# Nodes =  [2580556, 1203276401, 2580557, 2357713890, 2357713887, 2580559]
# Tags  =  ['name', 'Mellemvangs Alle', 'highway', 'residential']
#
# Id =  426402
# Nodes =  [2583454, 7556451998, 2583455]
# Tags  =  ['highway', 'unclassified', 'name', 'Hededammen']
#
# Id =  426403
# Nodes =  [1877057, 4949515076, 4949515080, 1024772485, 2583459]
# Tags  =  ['highway', 'residential', 'name', 'Hedegårdsvej']
#
# Id =  426405
# Nodes =  [935220, 3608450873, 2502102157, 1026836927]
# Tags  =  ['highway', 'tertiary', 'lanes', '3', 'lanes:backward', '2', 'lanes:forward', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Ringen', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'turn:lanes:backward', 'left;through|right']
#
# Id =  426406
# Nodes =  [2583469, 10304335, 2455239599, 4158227098, 10304336, 4158227093, 2583471]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Lenders Alle', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  426407
# Nodes =  [5046148, 1020791215]
# Tags  =  ['highway', 'path', 'name', 'Ribegade', 'surface', 'asphalt']
#
# Id =  427085
# Nodes =  [2592227, 2592225, 2592223, 2236847831, 2592221, 2586475, 2586474, 3685910954, 2586468, 2586466, 2586463, 2586461, 2236847800, 2586460]
# Tags  =  ['name', 'Kibsgårdsvej', 'highway', 'unclassified']
#
# Id =  427086
# Nodes =  [25230899, 3403951378, 4807810784, 4807810778, 11671964]
# Tags  =  ['highway', 'tertiary', 'lit', 'no', 'maxspeed', '80', 'name', 'Tarp Byvej', 'source:maxspeed', 'DK:rural', 'surface', 'asphalt']
#
# Id =  427087
# Nodes =  [11671964, 11671962, 11671961, 11671960, 11671958, 2586452, 31113568]
# Tags  =  ['name', 'Landemærket', 'highway', 'tertiary', 'surface', 'asphalt', 'cycleway', 'lane', 'maxspeed', '60', 'source:maxspeed', 'sign']
#
# Id =  427088
# Nodes =  [1025312523, 5220514276, 1025312526, 2503617946, 2586424, 3163535609, 1034045391, 6318938610]
# Tags  =  ['bicycle', 'no', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '60', 'name', 'Kjersing Ringvej', 'oneway', 'yes', 'surface', 'asphalt']
#
# Id =  427390
# Nodes =  [2503617966, 2589096]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'maxspeed', '50', 'name', 'Sukkertoppen', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  427391
# Nodes =  [2589156, 35217987, 35217986, 35217984, 35217983, 2501987270, 35217982, 2589154, 4158929783, 2589152, 2589151, 4158929779, 2501987247, 2589150, 4158929774, 35217996, 2589149, 4158929773, 2501987213, 2589147, 4158929771, 2501987203, 2589146]
# Tags  =  ['highway', 'tertiary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Umanakparken', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  427645
# Nodes =  [4900308661, 2589207, 1019631995, 2589204, 2589201, 20826353, 2589199, 1019725362, 2589195, 1019725322, 2589193, 4158929140, 1019725366, 2589191, 1019725400, 20826350, 4433242693, 2589187, 1019725294, 2589185, 2589182, 2589179, 2589176, 4433242698, 2589173, 1019725307, 1019725333, 2589170, 20826341, 2589167, 1019725347, 2589165, 2589104, 2589103, 2589112, 16279418, 2589116, 2501756776, 2589119, 4433242701, 16279426, 2589122, 1019729492, 2589124, 16279419, 2589128, 2589130, 4433242705, 2501756789, 2589132, 2589134, 2589135]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'maxspeed', '60', 'name', 'Grønlandsparken', 'oneway', 'yes', 'surface', 'asphalt']
#
# Id =  427646
# Nodes =  [35206830, 5077757444, 5077757447, 3781787985, 5603070688, 35206828]
# Tags  =  ['highway', 'residential', 'name', 'Ulvevej']
#
# Id =  427647
# Nodes =  [2590502, 4546394207, 203680057, 35206840, 6301988658, 1483408814, 2501756592, 3781784539, 2590503]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Vester Gjesingvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  427649
# Nodes =  [26614151, 1394661568, 26614150, 20826364, 26614084, 26614083, 203679831, 1019838317, 20826361, 20826360, 20826359, 20826358, 4469960394, 26614082, 4469960522, 2590505]
# Tags  =  ['highway', 'residential', 'name', 'Vestervangen', 'surface', 'asphalt']
#
# Id =  427650
# Nodes =  [2590507, 5603070705, 5603070706, 6147020]
# Tags  =  ['highway', 'residential', 'name', 'Golfvej']
#
# Id =  562985
# Nodes =  [1876510, 1026811052, 1026811029, 1876516]
# Tags  =  ['highway', 'footway']
#
# Id =  562986
# Nodes =  [2988445, 1876516, 1876513, 4157832498, 10302034, 6568223, 4157827214, 4157822083, 17903454, 4157823133, 6568225, 4025835492, 30939828]
# Tags  =  ['name', 'Rahbeks Alle', 'lanes', '2', 'highway', 'residential', 'surface', 'asphalt']
#
# Id =  562987
# Nodes =  [2988446, 1026811050, 2988450, 2988448, 8050541]
# Tags  =  ['name', 'Christian Winthers Vej', 'highway', 'residential', 'name:etymology:wikidata', 'Q981722']
#
# Id =  562988
# Nodes =  [2988453, 5335589338, 5335589344, 2988465, 4158227487, 2988461, 5335589336, 3001993022, 5343789010, 2988464]
# Tags  =  ['bicycle', 'yes', 'foot', 'yes', 'highway', 'path', 'name', 'Munkestien']
#
# Id =  1019398
# Nodes =  [10226695, 4685706983, 10224636, 30347541, 10224626, 4874968568]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Skjoldsgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1019399
# Nodes =  [4333439, 5077693, 5164829657, 4333440, 2503271258, 30883473]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Finsensgade', 'surface', 'asphalt']
#
# Id =  1019401
# Nodes =  [4333439, 1021783367, 1944468538, 4333433]
# Tags  =  ['name', 'Sverrigsgade', 'highway', 'residential']
#
# Id =  1019402
# Nodes =  [4333434, 2503271255, 5077694, 4333433, 1944468547, 1060561, 7134329350, 2502102109, 4333432, 59710320, 1061747, 1944637305, 1951789018, 31112642]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Østergade', 'surface', 'asphalt']
#
# Id =  1020087
# Nodes =  [4336082, 4898155706]
# Tags  =  ['cycleway:right', 'track', 'highway', 'tertiary', 'lanes', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Helgolandsgade', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1020088
# Nodes =  [4336067, 4157904437, 4336065, 14962136, 4336061, 4157904551, 4898678794, 4157904554, 4336060, 1913278897, 1203186309, 1203186312, 4336047]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'maxweight', '18', 'name', 'Nyhavnsgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1020089
# Nodes =  [4336088, 1203068310, 1203068208, 1203186325, 4336047, 4336045, 5304995399, 4898437438, 4336051, 4336053]
# Tags  =  ['destination:forward', 'Fanø;Trafikhavn;Museumsfyrskib', 'highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Gammel Færgevej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1020090
# Nodes =  [4336045, 4336044, 4336042, 4685706853, 4336039, 4336038, 4336037, 14962137, 4336035, 5304995461, 4336034, 4336032, 1568143471, 1568143429, 4336031, 4336030, 1061028]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Willemoesgade', 'surface', 'asphalt']
#
# Id =  1021965
# Nodes =  [4343128, 4343127, 4343125, 4343124]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Grundtvigs Alle', 'surface', 'asphalt']
#
# Id =  1021966
# Nodes =  [4343132, 4371599940, 4205214201, 4205214199, 4205214208, 4343136, 4343135, 4343134, 2384892]
# Tags  =  ['name', 'Glentevej', 'highway', 'unclassified']
#
# Id =  1021967
# Nodes =  [4343171, 4343169]
# Tags  =  ['highway', 'service']
#
# Id =  1021968
# Nodes =  [4343183, 6089909326, 6089909325, 1251873729, 6089909327, 4343181, 4343180, 21455779]
# Tags  =  ['highway', 'unclassified', 'name', 'Østre Kjersingvej', 'surface', 'asphalt']
#
# Id =  1021970
# Nodes =  [4343187, 6089909318, 1017463861, 1017463819, 4343191, 1017463846, 1017463849, 1017463884, 1017463892, 4343192]
# Tags  =  ['highway', 'residential', 'name', 'Granlunden']
#
# Id =  1023842
# Nodes =  [4351191, 1431761100, 1431761224, 2502712663, 4351190, 4982572796, 31353316]
# Tags  =  ['highway', 'unclassified', 'name', 'Gravlundvej', 'surface', 'asphalt']
#
# Id =  1024347
# Nodes =  [5080397, 5080399, 2583481, 2574657, 11563819, 4343129, 4343127, 3626507076, 3626507057, 10304322, 11563817, 1456934370, 1456934135, 2583475]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Ewalds Alle', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1024349
# Nodes =  [1290472938, 34537372]
# Tags  =  ['cycleway', 'lane', 'highway', 'secondary', 'maxspeed', '70', 'name', 'Vestkystvej', 'ncn', 'yes', 'ncn_ref', '1', 'ref', '463', 'surface', 'asphalt']
#
# Id =  1212312
# Nodes =  [2591620, 2289552956, 4336038, 14962138, 5046127]
# Tags  =  ['highway', 'tertiary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Cort Adelers Gade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1212314
# Nodes =  [5046135, 1913278086, 1913278075, 5284603187, 603622357, 4835671407, 5046138]
# Tags  =  ['highway', 'primary', 'int_ref', 'E 20', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Toldbodvej', 'ref', 'E 20', 'surface', 'asphalt']
#
# Id =  1212315
# Nodes =  [57857370, 5428705898, 13796214, 5046143, 4493364185, 5046142, 59710139, 5284602803, 1796908624, 13796213]
# Tags  =  ['highway', 'secondary', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Østre Havnevej', 'ref', '447', 'source:maxspeed', 'sign', 'surface', 'asphalt']
#
# Id =  1212316
# Nodes =  [7484353, 4824575737, 6551107531, 5046148, 4904977283, 4028181718, 4028181721, 3379206520, 8050538, 4602287110]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'lit', 'yes', 'maxspeed', '50', 'name', 'Exnersgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1212549
# ...
#
# Id =  1881394
# Nodes =  [662935, 1607309619, 1105860206, 8088721, 3199261730, 1827788246, 1607593952, 424570421, 3199261750, 1607326725, 1668958509]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Gustav Johannsens Vej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881395
# Nodes =  [1003108946, 8088720, 4006719432, 1607313710, 1827788243, 8088721]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Junggreensvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban']
#
# Id =  1881396
# Nodes =  [8088724, 6199576309, 3199261727, 69361762, 1126380983, 1126385447, 6161353498, 1668945736, 6654604755, 1668941762]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Philip Schous Vej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881397
# Nodes =  [8088726, 1668958467, 3199261749, 6077761164, 6819930442, 1104592836, 7317131312, 1668945730, 6654604743, 1668941745]
# Tags  =  ['cycleway', 'track', 'highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'N. Jespersens Vej', 'oneway', 'no', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  1881398
# Nodes =  [662936, 1668938701]
# Tags  =  ['foot', 'no', 'highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Julius Valentiners Vej', 'oneway', 'yes', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881399
# Nodes =  [279897663, 3199261729, 1669421661, 982305385, 3199261732, 8088727]
# Tags  =  ['bicycle', 'yes', 'highway', 'footway', 'name', 'P.G. Ramms Alle']
#
# Id =  1881400
# Nodes =  [1668938705, 1611118103, 1611821030, 8088731, 8088729, 1612806698, 8088732]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'H. Schneekloths Vej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881401
# Nodes =  [8088732, 7425152953, 8088733, 1612820277, 8088735]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Ewaldsensvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881402
# Nodes =  [8088733, 1668958482, 8088736]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Frøbels Alle', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881403
# Nodes =  [8088738, 1304791540, 1577150581, 1304791543, 279897584]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Ved Lindevangen', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881404
# Nodes =  [287651763, 5487907103, 361389281, 6069391567, 576757, 6069391565, 576754]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'H.V. Nyholms Vej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881405
# Nodes =  [369902569, 3888266569, 8088739]
# Tags  =  ['cycleway', 'opposite_lane', 'highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Lindevangs Alle', 'oneway', 'yes', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881440
# Nodes =  [8089129, 8089130, 8089128]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Hornemansgade', 'oneway', 'yes', 'oneway:bicycle', 'no', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'wikidata', 'Q12317227', 'wikipedia', 'da:Hornemansgade']
#
# Id =  1881441
# Nodes =  [8089131, 2119882509, 8089129]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Kong Oscars Gade', 'oneway', 'yes', 'oneway:bicycle', 'no', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881442
# Nodes =  [8089127, 298747124]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Weysesgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881444
# Nodes =  [8089140, 298747119]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Heisesgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881446
# Nodes =  [8089138, 298747115]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'H.C. Lumbyes Gade', 'source:maxspeed', 'sign', 'surface', 'paved']
#
# Id =  1881447
# Nodes =  [7487095, 8089141, 8089616]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Helsingborggade', 'source:maxspeed', 'DK:zone:40', 'wikidata', 'Q12316157', 'wikipedia', 'da:Helsingborggade']
#
# Id =  1881448
# Nodes =  [8089156, 8089155, 8089623, 8089615]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Thomas Laubs Gade', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881451
# Nodes =  [8089159, 8089158]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Fanøgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'wikidata', 'Q12311066', 'wikipedia', 'da:Fanøgade (Østerbro)']
#
# Id =  1881452
# Nodes =  [294222476, 8089226, 8089227]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Otto Mallings Gade', 'parking:lane:both', 'diagonal', 'sidewalk', 'both', 'source', 'dk:zone40', 'surface', 'asphalt']
#
# Id =  1881453
# Nodes =  [8089219, 8089226]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Bechgaardsgade', 'parking:lane:both', 'diagonal', 'sidewalk', 'both', 'source:maxspeed', 'sign', 'surface', 'asphalt']
#
# Id =  1881454
# Nodes =  [8089220, 8089227, 7372303147, 7372303146, 8089228]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Lange-Müllers Gade', 'source:maxspeed', 'sign']
#
# Id =  1881456
# Nodes =  [8089263, 7487096]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Hjelmsgade', 'source:maxspeed', 'DK:zone:40']
#
# Id =  1881457
# Nodes =  [7326848643, 7326848644, 4200058004, 500852749, 2119882494]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Christiansmindevej', 'oneway', 'yes', 'oneway:bicycle', 'no', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881458
# Nodes =  [2119882494, 5759484696, 7368796858]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'maxspeed:advisory', '30', 'name', 'Strynøgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881459
# Nodes =  [8089270, 7323741264]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Musholmgade', 'sidewalk', 'both', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881460
# Nodes =  [8089272, 8089273]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Romsøgade', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881462
# Nodes =  [8089399, 500852983, 5333603262, 8089401, 4200058001, 5305524750, 5333603264, 5305524749, 1458716963, 8089403]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Hjortøgade', 'parking:lane:both', 'parallel', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881463
# Nodes =  [8085621, 283564214]
# Tags  =  ['highway', 'unclassified', 'maxspeed', '40', 'name', 'Marmorbroen', 'source:maxspeed', 'DK:zone:40', 'surface', 'sett']
#
# Id =  1881466
# Nodes =  [8089405, 283564252]
# Tags  =  ['highway', 'unclassified', 'lanes', '2', 'lit', 'yes', 'maxspeed', '40', 'name', 'Tøjhusgade', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881480
# Nodes =  [1080519958, 5247001115, 1061673810]
# Tags  =  ['highway', 'tertiary', 'lit', 'yes', 'maxspeed', '40', 'name', 'Edvard Griegs Gade', 'name:etymology:wikidata', 'Q80621', 'source:maxspeed', 'sign', 'surface', 'asphalt', 'wikidata', 'Q12309377', 'wikipedia', 'da:Edvard Griegs Gade']
#
# Id =  1881481
# Nodes =  [8089602, 430333974, 8089608]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Bellmans Plads', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881482
# Nodes =  [8089609, 298747116]
# Tags  =  ['highway', 'footway', 'created_by', 'Potlatch 0.9c']
#
# Id =  1881484
# Nodes =  [8089618, 2119882518, 8089617]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Marthagade', 'parking:lane:left', 'perpendicular', 'parking:lane:right', 'diagonal', 'sidewalk', 'both', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881487
# Nodes =  [8089659, 8089658]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Livøgade', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881489
# Nodes =  [8089661, 5305138756, 5305138751, 8089662]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '40', 'name', 'Kristineberg', 'source:maxspeed', 'DK:zone:40', 'surface', 'asphalt']
#
# Id =  1881490
# Nodes =  [4199695891, 4199695892, 4199695893, 4199695896]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'lanes', '4', 'lanes:backward', '3', 'lanes:forward', '1', 'lit', 'yes', 'maxspeed', '50', 'name', 'Sejrøgade', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'turn:lanes:backward', 'through|through|right']
#
# Id =  1881533
# Nodes =  [8091686, 8096077, 8096079, 8096080, 8096083, 336345070, 8096084, 1623889064, 8096086, 8096089, 8096091, 8096092, 403828341, 8096095, 1311853939, 8096099, 8096100, 8096104, 8096105, 8091687, 7174483191, 2914093945, 2914093950, 2206949052, 473193094]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Bisiddervej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881534
# Nodes =  [8091689, 8096076, 8096078, 8096081, 403829815, 8096082, 8096085, 1623889069, 8096087, 8096088, 1246218094, 8096090, 8096093, 8096094, 1311853936, 18176443, 8096098, 8096101, 8096103, 8096106, 8091688, 7174483190, 1607361320, 2914093946, 1607361311, 793289]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Oldermandsvej']
#
# Id =  1881535
# Nodes =  [18178303, 2334760884, 367884424, 375772806, 2341016540, 2914060858, 18178302, 375772807, 86688368, 2914060860, 8091698, 8091697, 8091696, 8091695, 505394225, 8091694, 8091693, 8091692, 5340564447, 5340564444]
# Tags  =  ['cycleway', 'track', 'highway', 'tertiary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Skoleholdervej', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  1881536
# Nodes =  [25506293, 297716827, 1964320882, 2913523457, 2913523460, 1964320673, 8091698]
# Tags  =  ['foot', 'yes', 'highway', 'cycleway']
#
# Id =  1881692
# Nodes =  [368949860, 4849476093, 299587240, 8091709, 303114207, 8091710]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Sokkelundsvej', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban']
#
# Id =  1881693
# Nodes =  [8091711, 8091708]
# Tags  =  ['lit', 'yes', 'name', 'Rytterbakken', 'highway', 'residential']
#
# Id =  1881694
# Nodes =  [8091712, 8091707]
# Tags  =  ['lit', 'yes', 'name', 'Svendelodden', 'highway', 'residential']
#
# Id =  1881695
# Nodes =  [8091713, 8091706]
# Tags  =  ['lit', 'yes', 'name', 'Mesterstien', 'highway', 'residential']
#
# Id =  1881696
# Nodes =  [8096058, 8091697, 8096057, 297925046, 8096055, 8096058]
# Tags  =  ['lit', 'yes', 'name', 'Præstelængen', 'oneway', 'yes', 'highway', 'residential']
#
# Id =  1881697
# Nodes =  [8091696, 8096061, 1660766312, 8096059]
# Tags  =  ['lit', 'yes', 'name', 'Degnestavnen', 'oneway', 'yes', 'highway', 'residential']
#
# Id =  1881698
# Nodes =  [8091695, 8096062, 1660766317, 4315929947, 8096060]
# Tags  =  ['lit', 'yes', 'name', 'Ringertoften', 'highway', 'residential']
#
# Id =  1881700
# Nodes =  [8096063, 2583448480, 8096065, 4315929955, 4315929958, 1467921236, 8096067, 4315931592, 2583448510, 8091694]
# Tags  =  ['lit', 'yes', 'name', 'Gravervænget', 'highway', 'residential']
#
# Id =  1881701
# Nodes =  [8096068, 2583448482, 4315929966, 8096072, 8096070, 4315931602, 2583448515, 8091693]
# Tags  =  ['lit', 'yes', 'name', 'Klokkerhøjen', 'highway', 'residential']
#
# Id =  1881702
# Nodes =  [2583448522, 4315931610, 371496403, 371496404, 4315929975, 2583448493]
# Tags  =  ['lit', 'yes', 'name', 'Møllerlodden', 'highway', 'residential']
#
# Id =  1881704
# Nodes =  [8096078, 8096079]
# Tags  =  ['lit', 'yes', 'name', 'Vagtmestervej', 'highway', 'service']
#
# Id =  1881705
# Nodes =  [8096083, 2048179633, 403829815]
# Tags  =  ['highway', 'service', 'lit', 'yes', 'name', 'Tøjmestervej', 'surface', 'asphalt']
#
# Id =  1881706
# Nodes =  [8096087, 8096086]
# Tags  =  ['lit', 'yes', 'name', 'Sadelmagervej', 'highway', 'service']
#
# Id =  1881707
# Nodes =  [8096090, 8096091]
# Tags  =  ['lit', 'yes', 'name', 'Buntmagervej', 'highway', 'service']
#
# Id =  1881708
# Nodes =  [8096094, 8096095]
# Tags  =  ['name', 'Tøndebindervej', 'highway', 'service']
#
# Id =  1881709
# Nodes =  [8096098, 8096099]
# Tags  =  ['lit', 'yes', 'name', 'Stenhuggervej', 'highway', 'service']
#
# Id =  1881710
# Nodes =  [8096103, 8096104]
# Tags  =  ['lit', 'yes', 'name', 'Teglbrændervej', 'highway', 'service']
#
# Id =  1881711
# Nodes =  [18176438, 18176437, 18176430, 6401546317, 18176429, 18176425, 18176423, 18176418]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Frimestervej']
#
# Id =  1881784
# Nodes =  [277056689, 836154800]
# Tags  =  ['bicycle', 'yes', 'cycleway', 'lane', 'foot', 'yes', 'highway', 'tertiary', 'lanes', '5', 'lanes:backward', '2', 'lanes:forward', '3', 'lit', 'yes', 'maxspeed', '50', 'name', 'Vandværksviadukten', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt', 'turn:lanes:backward', 'through|right', 'turn:lanes:forward', 'left;through|through;right|right']
#
# Id =  1881785
# Nodes =  [8084811, 1369094557, 8096858, 4895451162, 291421100, 8096857]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Milosvej', 'surface', 'asphalt']
#
# Id =  1881791
# Nodes =  [8096858, 6985392430, 8084923, 8327478, 8327473]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Parosvej', 'surface', 'asphalt']
#
# Id =  1881805
# Nodes =  [8097117, 280182243, 5608268283, 5608268285, 5608268287, 5608268289, 281692943, 5608268291, 5608268301, 5608268292, 1570026028, 1426406347]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Bjørnbaksvej', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881808
# Nodes =  [8097154, 5450247702, 5450247700, 5450247706, 5450247704, 8097160]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'maxspeed', '50', 'name', 'Kløvervænget', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881809
# Nodes =  [8097156, 8097161]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'name', 'Kastrupvænge', 'surface', 'asphalt']
#
# Id =  1881810
# Nodes =  [8097157, 8097162]
# Tags  =  ['highway', 'residential', 'lanes', '2', 'maxspeed', '50', 'name', 'Banevænget', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881811
# Nodes =  [8097159, 1871043861, 8097163]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Skovmarken', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881812
# Nodes =  [8089419, 1106829493, 3377116523]
# Tags  =  ['highway', 'primary', 'lit', 'yes', 'maxspeed', '50', 'name', 'Christians Brygge', 'ref', 'O2', 'surface', 'asphalt']
#
# Id =  1881814
# Nodes =  [8097282, 5010268301, 8097233, 364111203, 3625272521, 8032467]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Skånegade', 'parking:lane:right', 'perpendicular', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881815
# Nodes =  [8097283, 8097232, 8097235, 619883064]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'maxspeed', '50', 'name', 'Nordlandsgade', 'sidewalk', 'both', 'source:maxspeed', 'DK:urban', 'surface', 'asphalt']
#
# Id =  1881816
# Nodes =  [7397303, 7241055573, 5298316571, 277635979, 5298316586, 5298316566, 5298316572]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Frankrigsgade', 'sidewalk', 'both', 'surface', 'asphalt']
#
# Id =  1881817
# Nodes =  [8097236, 7199832088, 5298340115, 13091934, 2933627628, 8321015]
# Tags  =  ['highway', 'residential', 'lit', 'yes', 'name', 'Spaniensgade', 'surface', 'asphalt']

# %%
db_cursor.execute("""SELECT count(*) FROM osm_copy_way;""")
Num_rows=db_cursor.fetchall() 
print("Num Rows Table Ways is:",Num_rows)
highway=['motorway','trunk','primary','secondary','tertiary','unclassified','residential']
# Out:
# Num Rows Table Ways is: [(4969424,)]

# %%
list_highway=list()
for idx in highway:
    print(idx)
    db_cursor.execute("""CREATE TABLE highway_"""+idx+"""
      AS (SELECT *FROM osm_copy_way WHERE tags::varchar LIKE '%"""+idx+"""%');""")
    db_cursor.execute("""SELECT count(*) FROM highway_"""+idx+""";""")
    Num_rows=db_cursor.fetchall() 
    print("Num Rows Table "+idx+" Ways is:",Num_rows)
    
    db_cursor.execute("""CREATE TABLE highway_"""+idx+"""_nodes
                       AS(SELECT r.*
                            , (ARRAY (
                             SELECT CAST(n.lat AS FLOAT)/10000000
                             FROM   unnest(r.nodes) WITH ORDINALITY AS a( id, ord)
                             JOIN   planet_osm_nodes n ON n.id = a.id
                             ORDER  BY a.ord
                             )
                              ) AS lat
                            , (ARRAY (
                             SELECT CAST(n.lon AS FLOAT)/10000000
                             FROM   unnest(r.nodes) WITH ORDINALITY AS a( id, ord)
                             JOIN   planet_osm_nodes n ON n.id = a.id
                             ORDER  BY a.ord
                             )
                              ) AS lon                                                                            
                       FROM highway_"""+idx+""" r);""")

    db_cursor.execute("""DROP TABLE highway_"""+idx+""";""")

    db_cursor.execute("""SELECT id, nodes, tags,lat,lon FROM highway_"""+idx+"""_nodes ORDER BY id;""")
    way_records = db_cursor.fetchall() 
    ArrayWay=list()
    for row in way_records:
        
       ArrayCorr=list()
       roadID=row[0]
    
    
       for index in range(len(row[3])):
            
            nodes=row[1]
            lat=row[3]
            lon=row[4]
            Var=[nodes[index],lon[index],lat[index],roadID]
            ArrayCorr.append(Var)
       ArrayWay.append(ArrayCorr) 
    list_highway.append(ArrayWay)
# Out:
# motorway
# Num Rows Table motorway Ways is: [(4087,)]
# trunk
# Num Rows Table trunk Ways is: [(1404,)]
# primary
# Num Rows Table primary Ways is: [(8092,)]
# secondary
# Num Rows Table secondary Ways is: [(16509,)]
# tertiary
# Num Rows Table tertiary Ways is: [(46301,)]
# unclassified
# Num Rows Table unclassified Ways is: [(41333,)]
# residential
# Num Rows Table residential Ways is: [(185830,)]

# %%
db_cursor.close()
connection.close()
print("PostgreSQL connection is closed")

# %%
import os
from shapely.geometry import MultiPoint, mapping
import shapely.wkt
import shapefile
import shapely.wkt
import geopandas as gpd
import pandas as pd
from sys import argv
import csv
import osgeo.ogr, osgeo.osr #we will need some packages
from osgeo import ogr #and one more for the creation of a new field
import fiona
from fiona.crs import from_epsg
from osgeo import  ogr, osr
cont=0
array_highway=list()
for Arraway in list_highway:

    print(highway[cont])
    print(len(Arraway))
    features = list()
    for feature in Arraway:
        # Create a Multipoint object based on the array of points
        # Append to the list of Multipoint objects
        multipoint = ogr.Geometry(ogr.wkbMultiPoint)
        point=[]
        for coords in feature:
            point = ogr.Geometry(ogr.wkbPoint)
            point.AddPoint(*coords[1:3])
            multipoint.AddGeometry(point)

        features.append(multipoint)
        
    print('funciona geometry')
    shape= list()
    for idx in range(len(features)):
        shape.append(shapely.wkt.loads(features[idx].ExportToWkt()))
    new_pol =shapely.ops.cascaded_union(shape)
    array_highway.append(new_pol)
    print('longitud de grupo de shape',len(shape))
    print('longitud de grupo de features',len(features))
    print('longitud de grupo de array_highway',len(array_highway))
    
    
    print('funciona shapely')

    # Define a polygon feature geometry with one attribute
    schema = {
        'geometry': 'MultiPoint',
        'properties': {'id': 'int'},
    }
    # read  Shapefile
    with fiona.open('Layer'+highway[cont]+'.shp', 'w',crs=from_epsg(4326),driver='ESRI Shapefile',schema=schema) as c:
        ## If there are multiple geometries, put the "for" loop here
        c.write({
            'geometry': mapping(array_highway[cont]),
            'properties': {'id': 123},
        })
    print('funciona fiona')
    shape=None
    new_pol=None
    cont=cont+1
    print(cont)

# %%
import sys
from pandas import DataFrame
from qgis.core import Qgis, QgsProject, QgsMapSettings, QgsLayerDefinition,QgsRasterLayer
from pathlib import Path 
# Tell Python where you will get processing from
sys.path.append(r'C:\OSGeo4W64\apps\qgis\python\plugins')
import processing
import numpy as np
from sklearn.neighbors import NearestNeighbors
from pandas import DataFrame

LAT_samples=list()
LON_samples=list()

for type_road in range(len(list_highway)):
    for num_roads in range(len(list_highway[type_road])):
        for num_points in range(len(list_highway[type_road][num_roads])):
            for idx,XY in enumerate(list_highway[type_road][num_roads][num_points][1:3]):
                if (idx==0):
                    LAT_samples.append(XY)
                else:
                    LON_samples.append(XY)      
samples=np.column_stack((LAT_samples  ,LON_samples))  
print(np.shape(samples))
df = DataFrame (samples,columns=['Latitude','Longitude'])

# %%
df.drop_duplicates(keep="first",inplace=True)
df.shape

# %%
neigh = NearestNeighbors(n_neighbors=100
                         , radius=6)
neigh.fit(df)
search=neigh.kneighbors([[9.3878187, 55.002422]], 8, return_distance=True)

# %%
search

# %%
from qgis.analysis import QgsNativeAlgorithms
from qgis.core import (
     QgsApplication,
     QgsProcessingFeedback,
     QgsVectorLayer
)
QgsApplication.setPrefixPath(r'C:\OSGeo4W64\apps\qgis', True)
qgs = QgsApplication([], False)
qgs.initQgis()
sys.path.append(r'C:\OSGeo4W64\apps\qgis\python\plugins')

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
plt.ion()

import processing
from processing.core.Processing import Processing
Processing.initialize()
QgsApplication.processingRegistry().addProvider(QgsNativeAlgorithms())
for alg in QgsApplication.processingRegistry().algorithms():
        print(alg.id(), "--->", alg.displayName())

# %%
source = r"C:\Users\daniel\Pictures\Maps\Secondary.geojson"
inputvector = QgsVectorLayer(r"C:\Users\daniel\Pictures\Maps\Secondary.geojson")
fig, ax = plt.subplots(figsize = (20,20))
gpd.read_file(source).plot(ax=ax);

# %%
from ipywidgets import IntSlider
slider=IntSlider()
slider

# %%
from ipyleaflet import *
mapa=Map(center=(56,10),zoom=7,basemap=basemaps.OpenStreetMap.France)
display(mapa)

# %%
import json
# Open GeoJson file and load data
with open(r"C:\Users\daniel\Pictures\Maps\probando.geojson") as f:
    geojson = json.load(f)

# %%
from pandas.io.json import json_normalize

features = geojson['features']
json_normalize(features)

# %%
with open(r"C:\Users\daniel\Pictures\Maps\Secondary.geojson") as f:
    geojson1 = json.load(f)

# %%
features = geojson1['features']
json_normalize(features)

# %%
from ipyleaflet import GeoJSON

geo = GeoJSON(data=geojson)
mapa.add_layer(geo)
mapa
